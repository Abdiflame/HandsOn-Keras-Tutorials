# %%
from sklearn.cluster import KMeans
import numpy as np
from array import *
import matplotlib.pyplot as plt

# %%
mean = 0
cov = 10

x = np.random.normal(mean, cov, 200)
X = x.reshape(100,2)

# Pred
kmeans = KMeans(n_clusters = 5, random_state = 1).fit(X)
pred = kmeans.predict(X)

print("Cluster ID for each point")
print(kmeans.labels_)
print("Coordinates of centroids")
print(kmeans.cluster_centers_)

plt.figure(figsize=(12, 12))
plt.subplot(221)
plt.scatter(X[:, 0], X[:, 1], c = pred)
plt.title("KNN")
plt.show()
# Out:
# Cluster ID for each point
# [1 0 1 4 3 1 3 0 3 0 3 3 1 1 3 1 0 1 1 4 1 0 2 3 2 3 3 0 2 0 0 4 4 4 4 0 0
#  0 1 1 2 0 4 3 1 2 0 3 4 1 4 2 1 4 3 1 0 0 0 0 3 2 2 4 0 1 3 0 3 1 2 0 4 4
#  2 0 1 1 0 0 2 3 1 2 1 0 0 4 1 0 0 1 0 3 3 0 0 1 2 1]
# Coordinates of centroids
# [[ -3.59626558   9.88028178]
#  [  8.31366092  -4.86581829]
#  [-17.50653869   0.16848467]
#  [ 14.91964727  11.56168964]
#  [ -4.92039474 -13.10274112]]
